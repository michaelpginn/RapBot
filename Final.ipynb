# %% [markdown]
# # Final Notebook - Rap Generator

# %% [markdown]
# Nowadays, mainstream music has become so formulaic that a computer could probably write it. I decided to put that to the test by creating a program to generate song lyrics for a given artist.
#
# ## Strategy
# 1. First, we will fetch collections of lyrics for a given artist.
# 2. Next, generate an n-gram model for that artist.
# 3. Define a stress and rhyme pattern for a song.
# 4. Repeatedly generate n-grams, accepting only those that match the above pattern, until song is complete.

# %%
# Import our API keys
from utility.config import *

# We will use this package to make API calls
import requests
import urllib
from lyricsgenius import Genius

genius = Genius(ACCESS_TOKEN)

HEADERS = {'User-Agent': 'XY', 'Content-type': 'application/json', 'Authorization': 'Bearer ' + ACCESS_TOKEN}
API_URL = 'https://api.genius.com/'

# %% [markdown]
# First, let's decide which artist we are going to use. The following cell searches for a given artist with Genius's API. Enter in the artist for whom you'd like to generate lyrics–it will work better if they have a large discography.

# %%
artist_found = False
artist_id = ''
artist_name = ''

while not artist_found:
    print('What artist would you like to search for?')
    query = input().strip()
    
    # encode spaces
    params = urllib.parse.urlencode({'q': query}, quote_via=urllib.parse.quote)
    
    resp = requests.get(API_URL + 'search', headers=HEADERS, params=params).json()
    
    if len(resp['response']['hits']) == 0:
        print('No hits found')
        continue
    
    for hit in resp['response']['hits']:
        if hit['type'] == 'song':
            if hit['result']['primary_artist']['name'].lower() == query.lower():
                print('Did ' + query + ' sing \'' + hit['result']['title'] + '\'? Enter y for yes.')
                confirm = input()
                if confirm.strip() == 'y':
                    # We have found the right artist! Let's get out of here.
                    artist_id = hit['result']['primary_artist']['id']
                    artist_name = hit['result']['primary_artist']['name']
                    artist_found = True
                    break
    
print(artist_name)
print(artist_id)
# Out:
# What artist would you like to search for?
#  Eminem
# {'meta': {'status': 200}, 'response': {'hits': [{'highlights': [], 'index': 'song', 'type': 'song', 'result': {'annotation_count': 110, 'api_path': '/songs/235729', 'full_title': 'Rap God by\xa0Eminem', 'header_image_thumbnail_url': 'https://images.genius.com/058e2359838c93395c36119b48a2eff6.300x300x1.png', 'header_image_url': 'https://images.genius.com/058e2359838c93395c36119b48a2eff6.1000x1000x1.png', 'id': 235729, 'lyrics_owner_id': 22533, 'lyrics_state': 'complete', 'path': '/Eminem-rap-god-lyrics', 'pyongs_count': 6504, 'song_art_image_thumbnail_url': 'https://images.genius.com/058e2359838c93395c36119b48a2eff6.300x300x1.png', 'song_art_image_url': 'https://images.genius.com/058e2359838c93395c36119b48a2eff6.1000x1000x1.png', 'stats': {'unreviewed_annotations': 0, 'concurrents': 10, 'hot': False, 'pageviews': 17015201}, 'title': 'Rap God', 'title_with_featured': 'Rap God', 'url': 'https://genius.com/Eminem-rap-god-lyrics', 'song_art_primary_color': '#dd4448', 'song_art_secondary_color': '#701416', 'song_art_text_color': '#fff', 'primary_artist': {'api_path': '/artists/45', 'header_image_url': 'https://images.genius.com/a9f98b20f8aa7a32650a1dfa5f3de088.1000x445x1.jpg', 'id': 45, 'image_url': 'https://images.genius.com/c674178296f3d65792a66f851fbc62fc.900x900x1.png', 'is_meme_verified': True, 'is_verified': True, 'name': 'Eminem', 'url': 'https://genius.com/artists/Eminem', 'iq': 229664}}}, {'highlights': [], 'index': 'song', 'type': 'song', 'result': {'annotation_count': 58, 'api_path': '/songs/3958196', 'full_title': 'Killshot by\xa0Eminem', 'header_image_thumbnail_url': 'https://images.genius.com/0d746c83f61c44aff7a1a812271822c5.300x300x1.jpg', 'header_image_url': 'https://images.genius.com/0d746c83f61c44aff7a1a812271822c5.1000x1000x1.jpg', 'id': 3958196, 'lyrics_owner_id': 104344, 'lyrics_state': 'complete', 'path': '/Eminem-killshot-lyrics', 'pyongs_count': 1723, 'song_art_image_thumbnail_url': 'https://images.genius.com/b1da996dcb2acb56506b8e02612e8561.300x300x1.png', 'song_art_image_url': 'https://images.genius.com/b1da996dcb2acb56506b8e02612e8561.1000x1000x1.png', 'stats': {'unreviewed_annotations': 0, 'concurrents': 3, 'hot': False, 'pageviews': 6640406}, 'title': 'Killshot', 'title_with_featured': 'Killshot', 'url': 'https://genius.com/Eminem-killshot-lyrics', 'song_art_primary_color': '#e11b20', 'song_art_secondary_color': '#6a080b', 'song_art_text_color': '#fff', 'primary_artist': {'api_path': '/artists/45', 'header_image_url': 'https://images.genius.com/a9f98b20f8aa7a32650a1dfa5f3de088.1000x445x1.jpg', 'id': 45, 'image_url': 'https://images.genius.com/c674178296f3d65792a66f851fbc62fc.900x900x1.png', 'is_meme_verified': True, 'is_verified': True, 'name': 'Eminem', 'url': 'https://genius.com/artists/Eminem', 'iq': 229664}}}, {'highlights': [], 'index': 'song', 'type': 'song', 'result': {'annotation_count': 41, 'api_path': '/songs/5180439', 'full_title': 'Godzilla by\xa0Eminem (Ft.\xa0Juice\xa0WRLD)', 'header_image_thumbnail_url': 'https://images.genius.com/828acd1e1136e2e79248620d4ff2be4d.300x300x1.png', 'header_image_url': 'https://images.genius.com/828acd1e1136e2e79248620d4ff2be4d.600x600x1.png', 'id': 5180439, 'lyrics_owner_id': 8117646, 'lyrics_state': 'complete', 'path': '/Eminem-godzilla-lyrics', 'pyongs_count': 1102, 'song_art_image_thumbnail_url': 'https://images.genius.com/e7ec9f0d94b506dadfc6a34a801cd56d.300x300x1.png', 'song_art_image_url': 'https://images.genius.com/e7ec9f0d94b506dadfc6a34a801cd56d.600x600x1.png', 'stats': {'unreviewed_annotations': 0, 'concurrents': 8, 'hot': False, 'pageviews': 5602040}, 'title': 'Godzilla', 'title_with_featured': 'Godzilla (Ft.\xa0Juice\xa0WRLD)', 'url': 'https://genius.com/Eminem-godzilla-lyrics', 'song_art_primary_color': '#b41024', 'song_art_secondary_color': '#701528', 'song_art_text_color': '#fff', 'primary_artist': {'api_path': '/artists/45', 'header_image_url': 'https://images.genius.com/a9f98b20f8aa7a32650a1dfa5f3de088.1000x445x1.jpg', 'id': 45, 'image_url':  ...
# Did Eminem sing 'Rap God'? Enter y for yes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d7b1f800b827> in <module>
#      22             if hit['result']['primary_artist']['name'].lower() == query.lower():
#      23                 print('Did ' + query + ' sing \'' + hit['result']['title'] + '\'? Enter y for yes.')
# ---> 24                 confirm = input()
#      25                 if confirm.strip() == 'y':
#      26                     # We have found the right artist! Let's get out of here.
#
# ~/Library/Python/3.7/lib/python/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858             self._parent_ident,
#     859             self._parent_header,
# --> 860             password=False,
#     861         )
#     862
#
# ~/Library/Python/3.7/lib/python/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     899             except KeyboardInterrupt:
#     900                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 901                 raise KeyboardInterrupt("Interrupted by user") from None
#     902             except Exception as e:
#     903                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# Now, we must fetch a reasonable amount of songs for the artist. We will repeatedly query the Genius API for songs for the artist. We might also want to eliminate songs with features on them, since that will muddy our n-gram grammar. Note: this step should take quite a bit, as it has to make many API calls.

# %%
artist_songs = []

more_to_get = True
cur_page = 1 # Used to page through all songs

while more_to_get:
    params = {'sort': 'popularity', 'page': cur_page}
    resp = requests.get(API_URL + 'artists/' + str(artist_id) + '/songs', headers=HEADERS, params=params).json()
        
    if len(resp['response']['songs']) == 0:
        more_to_get = False
        break
        
    for song in resp['response']['songs']:
        # Let's make sure the song matches a few basic conditions
        # First: is the main artist correct?
        if not song['primary_artist']['id'] == artist_id:
            break
        
        # Next: is there a feature?
        if 'feat.' in song['title'].lower() or 'ft.' in song['title'].lower():
            break
            
        # If neither, we are good to go.
        artist_songs.append(song)
        print(song['title'])
    
    cur_page += 1
    
    if len(artist_songs) > 500:
        more_to_get = False
        break

print('Done. Got ' + str(len(artist_songs)) + ' songs.')
# Out:
# FEFE
# GOOBA
# GUMMO
# BILLY
# KOODA
# TATI
# YOKAI
# CHOCOLATÉ
# ScumLife
# Zeta Zero 0.5
# On The Regular
# BUBA
# GTL
# SINALØA
# Shinigami (死神)
# NINI
# Fuck Is You
# LEAH
# CHARLIE
# CRIMINAL*
# Alright
# Lose Yourself (Freestyle)
# PUNANI (Demo)
# NADA*
# SCUM
# Body Buildings
# International Gangstas (Original Version)
# Done. Got 27 songs.

# %% [markdown]
# Now, we will use these songs to generate a single n-gram model for the artist.

# %%
artist_songs
# Out:
# [{'annotation_count': 23,
#   'api_path': '/songs/3767821',
#   'full_title': 'FEFE by\xa06ix9ine (Ft.\xa0Murda\xa0Beatz & Nicki\xa0Minaj)',
#   'header_image_thumbnail_url': 'https://images.genius.com/455ffbf3409022786dc15470da6d93e9.300x160x1.png',
#   'header_image_url': 'https://images.genius.com/455ffbf3409022786dc15470da6d93e9.806x430x1.png',
#   'id': 3767821,
#   'lyrics_owner_id': 1395662,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-fefe-lyrics',
#   'pyongs_count': 250,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/986690d69bc839048896aa1d10d46356.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/986690d69bc839048896aa1d10d46356.640x640x1.png',
#   'stats': {'unreviewed_annotations': 1,
#    'concurrents': 2,
#    'hot': False,
#    'pageviews': 4342594},
#   'title': 'FEFE',
#   'title_with_featured': 'FEFE (Ft.\xa0Murda\xa0Beatz & Nicki\xa0Minaj)',
#   'url': 'https://genius.com/6ix9ine-fefe-lyrics',
#   'song_art_primary_color': '#14d3fb',
#   'song_art_secondary_color': '#59ecfc',
#   'song_art_text_color': '#000',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 14,
#   'api_path': '/songs/5545285',
#   'full_title': 'GOOBA by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/b9312d4def780caf7a6f59649a062981.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/b9312d4def780caf7a6f59649a062981.880x880x1.png',
#   'id': 5545285,
#   'lyrics_owner_id': 5748418,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-gooba-lyrics',
#   'pyongs_count': 185,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/38d97091049a4a8ffb2c0922b3e8149d.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/38d97091049a4a8ffb2c0922b3e8149d.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 3954603},
#   'title': 'GOOBA',
#   'title_with_featured': 'GOOBA',
#   'url': 'https://genius.com/6ix9ine-gooba-lyrics',
#   'song_art_primary_color': '#04f4fc',
#   'song_art_secondary_color': '#cbe485',
#   'song_art_text_color': '#000',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 27,
#   'api_path': '/songs/3266784',
#   'full_title': 'GUMMO by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/2780c8bb67b9468e91e92a5a35fa70e2.300x169x1.jpg',
#   'header_image_url': 'https://images.genius.com/2780c8bb67b9468e91e92a5a35fa70e2.1000x563x1.jpg',
#   'id': 3266784,
#   'lyrics_owner_id': 1627923,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-gummo-lyrics',
#   'pyongs_count': 197,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/b9f7c0646681972617b4e39bad3fc801.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/b9f7c0646681972617b4e39bad3fc801.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 3245810},
#   'title': 'GUMMO',
#   'title_with_featured': 'GUMMO',
#   'url': 'https://genius.com/6ix9ine-gummo-lyrics',
#   'song_art_primary_color': '#cc2527',
#   'song_art_secondary_color': '#740c0c',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 15,
#   'api_path': '/songs/3497224',
#   'full_title': 'BILLY by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.1000x1000x1.png',
#   'id': 3497224,
#   'lyrics_owner_id': 1505217,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-billy-lyrics',
#   'pyongs_count': 79,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 1,
#    'concurrents': 2,
#    'hot': False,
#    'pageviews': 1267899},
#   'title': 'BILLY',
#   'title_with_featured': 'BILLY',
#   'url': 'https://genius.com/6ix9ine-billy-lyrics',
#   'song_art_primary_color': '#f704f8',
#   'song_art_secondary_color': '#a30f9d',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 15,
#   'api_path': '/songs/3303780',
#   'full_title': 'KOODA by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/08815be5c1bd9c5cda759fba34c41c0d.300x169x1.jpg',
#   'header_image_url': 'https://images.genius.com/08815be5c1bd9c5cda759fba34c41c0d.1000x563x1.jpg',
#   'id': 3303780,
#   'lyrics_owner_id': 1740933,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-kooda-lyrics',
#   'pyongs_count': 86,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/9be5fe739c801feb501e8a406c0b9655.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/9be5fe739c801feb501e8a406c0b9655.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 4, 'hot': False, 'pageviews': 1226958},
#   'title': 'KOODA',
#   'title_with_featured': 'KOODA',
#   'url': 'https://genius.com/6ix9ine-kooda-lyrics',
#   'song_art_primary_color': '#d6370b',
#   'song_art_secondary_color': '#741009',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 17,
#   'api_path': '/songs/3693552',
#   'full_title': 'TATI by\xa06ix9ine (Ft.\xa0DJ\xa0SpinKing)',
#   'header_image_thumbnail_url': 'https://images.genius.com/7743538a2928c2a2ff91f1209e33a22c.300x169x1.jpg',
#   'header_image_url': 'https://images.genius.com/7743538a2928c2a2ff91f1209e33a22c.1000x563x1.jpg',
#   'id': 3693552,
#   'lyrics_owner_id': 4837420,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-tati-lyrics',
#   'pyongs_count': 103,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/27cea6a218c48c3474674094e9ef3329.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/27cea6a218c48c3474674094e9ef3329.640x640x1.png',
#   'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 1084324},
#   'title': 'TATI',
#   'title_with_featured': 'TATI (Ft.\xa0DJ\xa0SpinKing)',
#   'url': 'https://genius.com/6ix9ine-tati-lyrics',
#   'song_art_primary_color': '#fb04fb',
#   'song_art_secondary_color': '#929607',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 5,
#   'api_path': '/songs/2715090',
#   'full_title': 'YOKAI by\xa06ix9ine (Ft.\xa0ZillaKami)',
#   'header_image_thumbnail_url': 'https://images.genius.com/c1755314bb54c0c83b3f1d89c9156f6f.300x169x1.jpg',
#   'header_image_url': 'https://images.genius.com/c1755314bb54c0c83b3f1d89c9156f6f.1000x563x1.jpg',
#   'id': 2715090,
#   'lyrics_owner_id': 1154241,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-yokai-lyrics',
#   'pyongs_count': 14,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/a9e2484e4ae000cc17545848495bf343.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/a9e2484e4ae000cc17545848495bf343.1000x1000x1.jpg',
#   'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 62390},
#   'title': 'YOKAI',
#   'title_with_featured': 'YOKAI (Ft.\xa0ZillaKami)',
#   'url': 'https://genius.com/6ix9ine-yokai-lyrics',
#   'song_art_primary_color': '#d15219',
#   'song_art_secondary_color': '#840c2c',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 8,
#   'api_path': '/songs/3535376',
#   'full_title': 'CHOCOLATÉ by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.1000x1000x1.png',
#   'id': 3535376,
#   'lyrics_owner_id': 465645,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-chocolate-lyrics',
#   'pyongs_count': 8,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 59028},
#   'title': 'CHOCOLATÉ',
#   'title_with_featured': 'CHOCOLATÉ',
#   'url': 'https://genius.com/6ix9ine-chocolate-lyrics',
#   'song_art_primary_color': '#f704f8',
#   'song_art_secondary_color': '#a30f9d',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 6,
#   'api_path': '/songs/2265115',
#   'full_title': 'ScumLife by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/b626b945fdc3404f606e2f7368f406e9.300x55x1.png',
#   'header_image_url': 'https://images.genius.com/b626b945fdc3404f606e2f7368f406e9.975x180x1.png',
#   'id': 2265115,
#   'lyrics_owner_id': 2011860,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-scumlife-lyrics',
#   'pyongs_count': 10,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/5bae451787f3ba8997fa8999e285d890.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/5bae451787f3ba8997fa8999e285d890.500x500x1.jpg',
#   'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 56735},
#   'title': 'ScumLife',
#   'title_with_featured': 'ScumLife',
#   'url': 'https://genius.com/6ix9ine-scumlife-lyrics',
#   'song_art_primary_color': '#b70f1a',
#   'song_art_secondary_color': '#21090b',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 8,
#   'api_path': '/songs/3103009',
#   'full_title': 'Zeta Zero 0.5 by\xa06ix9ine (Ft.\xa0Dalyb, Famous\xa0Dex & Schlosser)',
#   'header_image_thumbnail_url': 'https://images.genius.com/ee4e9a0349c670793552105289148342.300x169x1.jpg',
#   'header_image_url': 'https://images.genius.com/ee4e9a0349c670793552105289148342.1000x563x1.jpg',
#   'id': 3103009,
#   'lyrics_owner_id': 3308817,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-zeta-zero-05-lyrics',
#   'pyongs_count': 10,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/59d73f4a900d580d0539e28790a557a4.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/59d73f4a900d580d0539e28790a557a4.632x632x1.jpg',
#   'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 55958},
#   'title': 'Zeta Zero 0.5',
#   'title_with_featured': 'Zeta Zero 0.5 (Ft.\xa0Dalyb, Famous\xa0Dex & Schlosser)',
#   'url': 'https://genius.com/6ix9ine-zeta-zero-05-lyrics',
#   'song_art_primary_color': '#7f7f7f',
#   'song_art_secondary_color': '#424242',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 5,
#   'api_path': '/songs/2918096',
#   'full_title': 'On The Regular by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/ed8b28e011d6d081624fbe6d3f3ead47.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/ed8b28e011d6d081624fbe6d3f3ead47.500x500x1.jpg',
#   'id': 2918096,
#   'lyrics_owner_id': 3308817,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-on-the-regular-lyrics',
#   'pyongs_count': 4,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/ed8b28e011d6d081624fbe6d3f3ead47.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/ed8b28e011d6d081624fbe6d3f3ead47.500x500x1.jpg',
#   'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 55317},
#   'title': 'On The Regular',
#   'title_with_featured': 'On The Regular',
#   'url': 'https://genius.com/6ix9ine-on-the-regular-lyrics',
#   'song_art_primary_color': '#647d2b',
#   'song_art_secondary_color': '#345c1c',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 6,
#   'api_path': '/songs/3535373',
#   'full_title': 'BUBA by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.1000x1000x1.png',
#   'id': 3535373,
#   'lyrics_owner_id': 2190286,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-buba-lyrics',
#   'pyongs_count': 2,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/0e858a12379a5dedcc4fbc25195d59f3.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 54403},
#   'title': 'BUBA',
#   'title_with_featured': 'BUBA',
#   'url': 'https://genius.com/6ix9ine-buba-lyrics',
#   'song_art_primary_color': '#f704f8',
#   'song_art_secondary_color': '#a30f9d',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 8,
#   'api_path': '/songs/5907867',
#   'full_title': 'GTL by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.1000x1000x1.png',
#   'id': 5907867,
#   'lyrics_owner_id': 7655824,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-gtl-lyrics',
#   'pyongs_count': 3,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 8, 'hot': False, 'pageviews': 21995},
#   'title': 'GTL',
#   'title_with_featured': 'GTL',
#   'url': 'https://genius.com/6ix9ine-gtl-lyrics',
#   'song_art_primary_color': '#fcf905',
#   'song_art_secondary_color': '#fbfb2a',
#   'song_art_text_color': '#000',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 6,
#   'api_path': '/songs/3358197',
#   'full_title': 'SINALØA by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/859ef2b1cd3882bdd81051014912a483.300x293x1.png',
#   'header_image_url': 'https://images.genius.com/859ef2b1cd3882bdd81051014912a483.899x879x1.png',
#   'id': 3358197,
#   'lyrics_owner_id': 2230302,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-sinala-lyrics',
#   'pyongs_count': 4,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/859ef2b1cd3882bdd81051014912a483.300x293x1.png',
#   'song_art_image_url': 'https://images.genius.com/859ef2b1cd3882bdd81051014912a483.899x879x1.png',
#   'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 20859},
#   'title': 'SINALØA',
#   'title_with_featured': 'SINALØA',
#   'url': 'https://genius.com/6ix9ine-sinala-lyrics',
#   'song_art_primary_color': '#21dd67',
#   'song_art_secondary_color': '#8bedb0',
#   'song_art_text_color': '#000',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 7,
#   'api_path': '/songs/707847',
#   'full_title': 'Shinigami (死神) by\xa06ix9ine (Ft.\xa0Bodega\xa0Bamz)',
#   'header_image_thumbnail_url': 'https://images.genius.com/2df43338c811d7ceca6b48474c7470e8.300x169x1.jpg',
#   'header_image_url': 'https://images.genius.com/2df43338c811d7ceca6b48474c7470e8.1000x563x1.jpg',
#   'id': 707847,
#   'lyrics_owner_id': 1534826,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-shinigami-lyrics',
#   'pyongs_count': 6,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/ebe8770a02672b87c6f10eaacd22198b.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/ebe8770a02672b87c6f10eaacd22198b.640x640x1.png',
#   'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 18583},
#   'title': 'Shinigami (死神)',
#   'title_with_featured': 'Shinigami (死神) (Ft.\xa0Bodega\xa0Bamz)',
#   'url': 'https://genius.com/6ix9ine-shinigami-lyrics',
#   'song_art_primary_color': '#8494c4',
#   'song_art_secondary_color': '#2a3659',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 5,
#   'api_path': '/songs/5926105',
#   'full_title': 'NINI by\xa06ix9ine (Ft.\xa0Leftside)',
#   'header_image_thumbnail_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.1000x1000x1.png',
#   'id': 5926105,
#   'lyrics_owner_id': 4733728,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-nini-lyrics',
#   'pyongs_count': None,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 4, 'hot': False, 'pageviews': 18546},
#   'title': 'NINI',
#   'title_with_featured': 'NINI (Ft.\xa0Leftside)',
#   'url': 'https://genius.com/6ix9ine-nini-lyrics',
#   'song_art_primary_color': '#fcf905',
#   'song_art_secondary_color': '#fbfb2a',
#   'song_art_text_color': '#000',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 7,
#   'api_path': '/songs/2265213',
#   'full_title': 'Fuck Is You by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/fb1282c3a2ba48dbdebfcd8cec1f4493.300x199x1.jpg',
#   'header_image_url': 'https://images.genius.com/fb1282c3a2ba48dbdebfcd8cec1f4493.1000x664x1.jpg',
#   'id': 2265213,
#   'lyrics_owner_id': 1534826,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-fuck-is-you-lyrics',
#   'pyongs_count': 2,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/1dbf703c74a302afd77a82219458c1c8.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/1dbf703c74a302afd77a82219458c1c8.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 15574},
#   'title': 'Fuck Is You',
#   'title_with_featured': 'Fuck Is You',
#   'url': 'https://genius.com/6ix9ine-fuck-is-you-lyrics',
#   'song_art_primary_color': '#845938',
#   'song_art_secondary_color': '#5d3e27',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 4,
#   'api_path': '/songs/5907861',
#   'full_title': 'LEAH by\xa06ix9ine (Ft.\xa0Akon)',
#   'header_image_thumbnail_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.1000x1000x1.png',
#   'id': 5907861,
#   'lyrics_owner_id': 4469304,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-leah-lyrics',
#   'pyongs_count': 1,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 4, 'hot': False, 'pageviews': 15287},
#   'title': 'LEAH',
#   'title_with_featured': 'LEAH (Ft.\xa0Akon)',
#   'url': 'https://genius.com/6ix9ine-leah-lyrics',
#   'song_art_primary_color': '#fcf905',
#   'song_art_secondary_color': '#fbfb2a',
#   'song_art_text_color': '#000',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 1,
#   'api_path': '/songs/5926104',
#   'full_title': 'CHARLIE by\xa06ix9ine (Ft.\xa0Smilez)',
#   'header_image_thumbnail_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.1000x1000x1.png',
#   'id': 5926104,
#   'lyrics_owner_id': 8674307,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-charlie-lyrics',
#   'pyongs_count': None,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/0553e46f16523eab4e16d0f79b72a095.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 14979},
#   'title': 'CHARLIE',
#   'title_with_featured': 'CHARLIE (Ft.\xa0Smilez)',
#   'url': 'https://genius.com/6ix9ine-charlie-lyrics',
#   'song_art_primary_color': '#fcf905',
#   'song_art_secondary_color': '#fbfb2a',
#   'song_art_text_color': '#000',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 1,
#   'api_path': '/songs/3705009',
#   'full_title': 'CRIMINAL* by\xa06ix9ine (Ft.\xa0Arcángel)',
#   'header_image_thumbnail_url': 'https://images.genius.com/c9296aec40d2aaa5a73b0bdf8af4bb64.300x200x1.jpg',
#   'header_image_url': 'https://images.genius.com/c9296aec40d2aaa5a73b0bdf8af4bb64.1000x668x1.jpg',
#   'id': 3705009,
#   'lyrics_owner_id': 4837420,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-criminal-lyrics',
#   'pyongs_count': 6,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/9135c970ff2a1c1337e79e8e843a4a53.300x298x1.png',
#   'song_art_image_url': 'https://images.genius.com/9135c970ff2a1c1337e79e8e843a4a53.640x636x1.png',
#   'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 6581},
#   'title': 'CRIMINAL*',
#   'title_with_featured': 'CRIMINAL* (Ft.\xa0Arcángel)',
#   'url': 'https://genius.com/6ix9ine-criminal-lyrics',
#   'song_art_primary_color': '#e9791d',
#   'song_art_secondary_color': '#a8320a',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 2,
#   'api_path': '/songs/3898145',
#   'full_title': 'Alright by\xa06ix9ine (Ft.\xa0L\xa0E A H & Warhol.SS)',
#   'header_image_thumbnail_url': 'https://images.genius.com/cb2e594c72466ee0eb2bbb7c7effc91e.300x169x1.jpg',
#   'header_image_url': 'https://images.genius.com/cb2e594c72466ee0eb2bbb7c7effc91e.1000x563x1.jpg',
#   'id': 3898145,
#   'lyrics_owner_id': 1505217,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-alright-lyrics',
#   'pyongs_count': None,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/7192138470fbe87683b47123f7c9017d.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/7192138470fbe87683b47123f7c9017d.500x500x1.jpg',
#   'stats': {'unreviewed_annotations': 1, 'hot': False},
#   'title': 'Alright',
#   'title_with_featured': 'Alright (Ft.\xa0L\xa0E A H & Warhol.SS)',
#   'url': 'https://genius.com/6ix9ine-alright-lyrics',
#   'song_art_primary_color': '#c48c34',
#   'song_art_secondary_color': '#58170e',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 2,
#   'api_path': '/songs/3940174',
#   'full_title': 'Lose Yourself (Freestyle) by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.921x921x1.png',
#   'id': 3940174,
#   'lyrics_owner_id': 1505217,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-lose-yourself-freestyle-lyrics',
#   'pyongs_count': 2,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.921x921x1.png',
#   'stats': {'unreviewed_annotations': 0, 'hot': False},
#   'title': 'Lose Yourself (Freestyle)',
#   'title_with_featured': 'Lose Yourself (Freestyle)',
#   'url': 'https://genius.com/6ix9ine-lose-yourself-freestyle-lyrics',
#   'song_art_primary_color': '#7f7f7f',
#   'song_art_secondary_color': '#424242',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 1,
#   'api_path': '/songs/5929865',
#   'full_title': 'PUNANI (Demo) by\xa06ix9ine (Ft.\xa0Tory\xa0Lanez)',
#   'header_image_thumbnail_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.921x921x1.png',
#   'id': 5929865,
#   'lyrics_owner_id': 9736166,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-punani-demo-lyrics',
#   'pyongs_count': None,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.921x921x1.png',
#   'stats': {'unreviewed_annotations': 0, 'hot': False},
#   'title': 'PUNANI (Demo)',
#   'title_with_featured': 'PUNANI (Demo) (Ft.\xa0Tory\xa0Lanez)',
#   'url': 'https://genius.com/6ix9ine-punani-demo-lyrics',
#   'song_art_primary_color': '#7f7f7f',
#   'song_art_secondary_color': '#424242',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 4,
#   'api_path': '/songs/6623307',
#   'full_title': 'NADA* by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.921x921x1.png',
#   'id': 6623307,
#   'lyrics_owner_id': 7430744,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-nada-lyrics',
#   'pyongs_count': 1,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.921x921x1.png',
#   'stats': {'unreviewed_annotations': 4, 'hot': False},
#   'title': 'NADA*',
#   'title_with_featured': 'NADA*',
#   'url': 'https://genius.com/6ix9ine-nada-lyrics',
#   'song_art_primary_color': '#7f7f7f',
#   'song_art_secondary_color': '#424242',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 0,
#   'api_path': '/songs/6565106',
#   'full_title': 'SCUM by\xa06ix9ine (Ft.\xa0Yung\xa0Tripp)',
#   'header_image_thumbnail_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.921x921x1.png',
#   'id': 6565106,
#   'lyrics_owner_id': 12200482,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-scum-lyrics',
#   'pyongs_count': None,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.921x921x1.png',
#   'stats': {'unreviewed_annotations': 0, 'hot': False},
#   'title': 'SCUM',
#   'title_with_featured': 'SCUM (Ft.\xa0Yung\xa0Tripp)',
#   'url': 'https://genius.com/6ix9ine-scum-lyrics',
#   'song_art_primary_color': '#7f7f7f',
#   'song_art_secondary_color': '#424242',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 0,
#   'api_path': '/songs/6515426',
#   'full_title': 'Body Buildings by\xa06ix9ine (Ft.\xa0Scum\xa0Gang)',
#   'header_image_thumbnail_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.921x921x1.png',
#   'id': 6515426,
#   'lyrics_owner_id': 10887884,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-body-buildings-lyrics',
#   'pyongs_count': None,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/dfcd9e4aaf2f01227887e0220db53191.921x921x1.png',
#   'stats': {'unreviewed_annotations': 0, 'hot': False},
#   'title': 'Body Buildings',
#   'title_with_featured': 'Body Buildings (Ft.\xa0Scum\xa0Gang)',
#   'url': 'https://genius.com/6ix9ine-body-buildings-lyrics',
#   'song_art_primary_color': '#7f7f7f',
#   'song_art_secondary_color': '#424242',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}},
#  {'annotation_count': 0,
#   'api_path': '/songs/5294420',
#   'full_title': 'International Gangstas (Original Version) by\xa06ix9ine',
#   'header_image_thumbnail_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#   'id': 5294420,
#   'lyrics_owner_id': 8331078,
#   'lyrics_state': 'complete',
#   'path': '/6ix9ine-international-gangstas-original-version-lyrics',
#   'pyongs_count': None,
#   'song_art_image_thumbnail_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#   'stats': {'unreviewed_annotations': 0, 'hot': False},
#   'title': 'International Gangstas (Original Version)',
#   'title_with_featured': 'International Gangstas (Original Version)',
#   'url': 'https://genius.com/6ix9ine-international-gangstas-original-version-lyrics',
#   'song_art_primary_color': '#fa040a',
#   'song_art_secondary_color': '#b8110f',
#   'song_art_text_color': '#fff',
#   'primary_artist': {'api_path': '/artists/1124097',
#    'header_image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'id': 1124097,
#    'image_url': 'https://images.genius.com/38d7e7c0e7bd19aae7c7a54796eba611.640x640x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': '6ix9ine',
#    'url': 'https://genius.com/artists/6ix9ine'}}]
